# %% [markdown]
# # Module 1 Quiz -- 15 Multiple Choice Questions
#
# **AI/ML Fundamentals -- Class 5 Lab**
#
# Instructions:
# - Read each question carefully.
# - Type your answer in the code cell below each question (e.g., `answer_1 = "b"`).
# - Use lowercase letters: `"a"`, `"b"`, `"c"`, or `"d"`.
# - Run the grading cell at the bottom to see your score.
# - Do NOT look at the grading cell before answering -- it contains the correct answers.

# %% [markdown]
# ---
# ### Section 1: AI/ML Basics (Q1-Q3)
#
# **Q1.** What is the relationship between AI and ML?
#
# - a) AI and ML are the same thing
# - b) ML is a subset of AI
# - c) AI is a subset of ML
# - d) They are completely unrelated

# %%
answer_1 = ""  # TODO: type your answer here, e.g. "b"

# %% [markdown]
# **Q2.** What differentiates deep learning from traditional ML?
#
# - a) It uses less data
# - b) It does not require computers
# - c) It uses multi-layer neural networks
# - d) It only works for image data

# %%
answer_2 = ""  # TODO: type your answer here

# %% [markdown]
# **Q3.** Supervised learning requires:
#
# - a) Unlabeled data only
# - b) A reward signal
# - c) Labeled input-output pairs
# - d) No data at all

# %%
answer_3 = ""  # TODO: type your answer here

# %% [markdown]
# ---
# ### Section 2: ML Types (Q4-Q7)
#
# **Q4.** The goal of unsupervised learning is to:
#
# - a) Predict a target variable
# - b) Discover hidden structure in data
# - c) Maximize a reward
# - d) Minimize labeled data usage

# %%
answer_4 = ""  # TODO: type your answer here

# %% [markdown]
# **Q5.** Unsupervised learning is used to:
#
# - a) Train with labeled examples
# - b) Discover hidden structure in data
# - c) Optimize a reward function
# - d) Perform real-time predictions

# %%
answer_5 = ""  # TODO: type your answer here

# %% [markdown]
# **Q6.** Reinforcement learning differs from other ML types because it:
#
# - a) Uses labeled data
# - b) Learns through trial-and-error with feedback
# - c) Requires no data
# - d) Only works with images

# %%
answer_6 = ""  # TODO: type your answer here

# %% [markdown]
# **Q7.** Customer segmentation is an example of:
#
# - a) Supervised learning
# - b) Reinforcement learning
# - c) Unsupervised learning
# - d) Rule-based programming

# %%
answer_7 = ""  # TODO: type your answer here

# %% [markdown]
# ---
# ### Section 3: Foundations (Q8-Q11)
#
# **Q8.** The i.i.d. assumption means data points are:
#
# - a) Dependent and differently distributed
# - b) Independent and identically distributed
# - c) Indexed and incrementally distributed
# - d) Inferred and inductively derived

# %%
answer_8 = ""  # TODO: type your answer here

# %% [markdown]
# **Q9.** Empirical risk is:
#
# - a) The theoretical minimum error
# - b) Calculated using training data
# - c) Always equal to true risk
# - d) Independent of the model

# %%
answer_9 = ""  # TODO: type your answer here

# %% [markdown]
# **Q10.** A model with high variance is likely:
#
# - a) Underfitting
# - b) Perfectly balanced
# - c) Overfitting
# - d) Using too little data

# %%
answer_10 = ""  # TODO: type your answer here

# %% [markdown]
# **Q11.** The purpose of optimization in ML is to:
#
# - a) Collect more data
# - b) Visualize results
# - c) Find parameters that minimize error
# - d) Remove outliers

# %%
answer_11 = ""  # TODO: type your answer here

# %% [markdown]
# ---
# ### Section 4: Applications (Q12-Q13)
#
# **Q12.** A fraud detection model has 99% accuracy but misses most fraud cases. This is likely due to:
#
# - a) Too many features
# - b) Class imbalance
# - c) Too much training data
# - d) High bias

# %%
answer_12 = ""  # TODO: type your answer here

# %% [markdown]
# **Q13.** Collaborative filtering works by:
#
# - a) Filtering out irrelevant data
# - b) Using similarities between users or items to make recommendations
# - c) Applying content-based rules only
# - d) Removing duplicate data

# %%
answer_13 = ""  # TODO: type your answer here

# %% [markdown]
# ---
# ### Section 5: Ethics (Q14-Q15)
#
# **Q14.** An AI hiring tool rejects more candidates from certain demographics. This is an example of:
#
# - a) Overfitting
# - b) Data leakage
# - c) Algorithmic bias
# - d) Feature engineering

# %%
answer_14 = ""  # TODO: type your answer here

# %% [markdown]
# **Q15.** A bank uses ML to deny loans but refuses to explain why to applicants. This raises concerns about:
#
# - a) Computational efficiency
# - b) Transparency and explainability
# - c) Data storage
# - d) Model accuracy

# %%
answer_15 = ""  # TODO: type your answer here

# %% [markdown]
# ---
# ## Auto-Grading
#
# Run the cell below to check your score. Do NOT modify the grading cell.

# %%
# ============================================================
# AUTO-GRADER -- Do not modify this cell
# ============================================================

correct_answers = {
    1: "b",   # ML is a subset of AI
    2: "c",   # Multi-layer neural networks
    3: "c",   # Labeled input-output pairs
    4: "b",   # Discover hidden structure
    5: "b",   # Discover hidden structure
    6: "b",   # Trial-and-error with feedback
    7: "c",   # Unsupervised learning
    8: "b",   # Independent and identically distributed
    9: "b",   # Calculated using training data
    10: "c",  # Overfitting
    11: "c",  # Find parameters that minimize error
    12: "b",  # Class imbalance
    13: "b",  # Similarities between users/items
    14: "c",  # Algorithmic bias
    15: "b",  # Transparency and explainability
}

student_answers = {
    1: answer_1,
    2: answer_2,
    3: answer_3,
    4: answer_4,
    5: answer_5,
    6: answer_6,
    7: answer_7,
    8: answer_8,
    9: answer_9,
    10: answer_10,
    11: answer_11,
    12: answer_12,
    13: answer_13,
    14: answer_14,
    15: answer_15,
}

score = 0
total = len(correct_answers)
unanswered = 0

print("=" * 50)
print("MODULE 1 QUIZ RESULTS")
print("=" * 50)
print()

for q_num in range(1, total + 1):
    student = student_answers[q_num].strip().lower()
    correct = correct_answers[q_num]

    if student == "":
        status = "UNANSWERED"
        unanswered += 1
    elif student == correct:
        status = "CORRECT"
        score += 1
    else:
        status = f"WRONG (your answer: {student}, correct: {correct})"

    print(f"  Q{q_num:2d}: {status}")

print()
print("=" * 50)
print(f"Score: {score}/{total} ({score/total:.0%})")
if unanswered > 0:
    print(f"Unanswered: {unanswered}")
if score == total:
    print("Perfect score.")
elif score >= 12:
    print("Strong performance. Review the ones you missed.")
elif score >= 9:
    print("Decent, but revisit the module content for the topics you missed.")
else:
    print("You should re-read the Module 1 content before moving on.")
print("=" * 50)
