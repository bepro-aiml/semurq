# %%
print("Hello")
# Out:
# Hello

# %%
age = 21
gpa = 4.2
name = "Shodiyor"
is_student = True
scores = [80, 84, 93, 69, 77]

print(age, type(age))
print(gpa, type(gpa))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 21 <class 'int'>
# 4.2 <class 'float'>
# True <class 'bool'>
# [80, 84, 93, 69, 77] <class 'list'>

# %%
def calculate_average(numbers):
  total = sum(numbers)
  count = len(numbers)
  return total / count

test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]
print(type(test1), type(test2))
print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# Out:
# <class 'list'> <class 'list'>
# Average 1: 84.0
# Average 2: 59.0

# %%
cities = ["Tashkent", "Samarkand", "Bukhara", "namangan", "fergana"]
for index, city in enumerate(cities):
  print(f"Index {index}:, {city}")
# Out:
# Index 0:, Tashkent
# Index 1:, Samarkand
# Index 2:, Bukhara
# Index 3:, namangan
# Index 4:, fergana

# %%
import random
exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores:", exam_scores)

avg = calculate_average(exam_scores)
print(f"Class average: {avg: .1f}")

if avg >= 60:
  print("Result: PASS")
else:
  print("Result: FAIL")
# Out:
# Scores: [9, 96, 97, 10, 30, 62, 71, 34, 44, 69]
# Class average:  52.2
# Result: FAIL
