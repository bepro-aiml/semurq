# %%
print("Hello, AI/ML!")
# Out:
# Hello, AI/ML!

# %%
age = 22
gpa = 3.85
name = "Aziz"
is_student = True
scores = [85, 92, 78, 95, 88]
print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 22 <class 'int'>
# 3.85 <class 'float'>
# Aziz <class 'str'>
# True <class 'bool'>
# [85, 92, 78, 95, 88] <class 'list'>

# %%
def calculate_average(numbers):
    total = sum(numbers)
    count = len(numbers)
    return total / count
test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]
print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %%
cities = ["Tashkent", "Samarkand", "Bukhara", "Namangan", "Fergana"]
for index, city in enumerate(cities):
    print(f"Index {index}: {city}")
# Out:
# Index 0: Tashkent
# Index 1: Samarkand
# Index 2: Bukhara
# Index 3: Namangan
# Index 4: Fergana

# %%
import random
exam_scores = [random.randint(0, 100) for _ in range(5)] # Создаем список из 5 случайных оценок
print("Scores:", exam_scores)
avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")
if avg >= 60:
    print("Result: PASS")
else:
    print("Result: FAIL")
# Out:
# Scores: [60, 79, 59, 42, 41]
# Class average: 56.2
# Result: FAIL
