# %% [markdown]
# # Module 2 — Class 6: Lab — Exploratory Data Analysis
#
# **Lecture:** [https://bepro-aiml.github.io/aiml-platform/#/module/2/class/6](https://bepro-aiml.github.io/aiml-platform/#/module/2/class/6)
#
# ## How this lab is graded
#
# Per the lecture: **after every plot, write one sentence — what did you observe, and what would you do differently when building a model?** That sentence is what gets you the points. Code that runs but isn't interpreted is worth zero.
#
# **Time budget:** 90 minutes. Solo or in pairs. Submit this notebook to your group repo at `module-2/class_6/submissions/<YourName>/`.
#
# ## Pick a Dataset
#
# Choose ONE before starting. State your choice in the cell below.
#
# - **Option A — Telco Churn.** 7,043 customers, 21 columns. Mix of categorical and numeric. Good for groupby and filtering practice.
#   https://www.kaggle.com/datasets/blastchar/telco-customer-churn
# - **Option B — Credit Card Fraud.** 284k transactions, 0.17% fraud. Severe class imbalance. Good for distribution plots and learning why accuracy fails.
#   https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %% [markdown]
# **My dataset:**
# **Why I picked it:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# df = pd.read_csv('your_dataset.csv')

# %% [markdown]
# ---
# ## Task 1 — Load and Peek
#
# Run `df.shape`, `df.dtypes`, `df.head()`. Each in its own cell so you can read each output.

# %%
# df.shape

# %%
# df.dtypes

# %%
# df.head()

# %% [markdown]
# ### ✍️ Observation
#
# Answer all in markdown:
# 1. How many rows and columns?
# 2. List 3 columns and what each represents in plain English.
# 3. Are any columns stored with the wrong dtype? (E.g., a number stored as object, a date stored as string.) If yes, which?
# 4. What is the **target column** for this dataset?

# %% [markdown]
# ---
# ## Task 2 — Missing Values

# %%
# Compute missing-value counts and missing-value fractions
# missing = df.isna().sum()
# pct = (df.isna().sum() / len(df) * 100).round(2)

# %% [markdown]
# ### ✍️ Observation
#
# 1. Which columns have missing values? What fraction?
# 2. *Quick Check 4 from the lecture:* If a column is 60% missing, what do you do first — drop, fill with 0, fill with mean, or investigate? Explain your reasoning.
# 3. Look up *Missing Not At Random (MNAR)*. Is there a column in your dataset where the missingness itself might be a signal? Which one and why?

# %% [markdown]
# ---
# ## Task 3 — Target Distribution
#
# Plot the target. Telco target = `Churn`. Fraud target = `Class`.

# %%
# Plot the count of each target class
# sns.countplot(df, x='your_target_col')

# %% [markdown]
# ### ✍️ Observation
#
# 1. What fraction of rows are positive (churn / fraud)?
# 2. Is this dataset balanced or imbalanced? Quantify it.
# 3. *Quick Check 3 from the lecture:* If your target is 0.2% positive, a model that always predicts 'no' gets 99.8% accuracy. What does this tell you about *which metric* you should care about? Name two metrics that handle imbalance better.

# %% [markdown]
# ---
# ## Task 4 — Numeric Features
#
# Histograms for at least **3** numeric columns.

# %%
# Pick 3 numeric columns and plot histograms
# fig, axes = plt.subplots(1, 3, figsize=(15, 4))
# sns.histplot(df, x='col1', kde=True, ax=axes[0])
# sns.histplot(df, x='col2', kde=True, ax=axes[1])
# sns.histplot(df, x='col3', kde=True, ax=axes[2])

# %% [markdown]
# ### ✍️ Observation (one paragraph per column)
#
# For **each** of the 3 columns:
# 1. Is the distribution skewed? Left, right, or symmetric?
# 2. Are there obvious outliers?
# 3. Would a `np.log1p` transform help? Why or why not?
# 4. What would you do with this column when building a model?

# %% [markdown]
# ---
# ## Task 5 — Categorical Features

# %%
# value_counts on at least 2 categorical columns
# df['some_categorical'].value_counts(normalize=True).head(10)

# %% [markdown]
# ### ✍️ Observation
#
# 1. Are any categories so rare (<1%) that you would group them into 'other'?
# 2. *Quick Check 1 from the lecture:* If a column has 99% of rows as the same value, what do you do with it? Why?

# %% [markdown]
# ---
# ## Task 6 — Feature vs Target
#
# Box (or violin) plot for at least **2** features split by the target class.

# %%
# sns.boxplot(df, x='target_col', y='feature_col')

# %% [markdown]
# ### ✍️ Observation
#
# For each feature you plotted:
# 1. Does the median differ between target classes?
# 2. Does the spread (IQR) differ?
# 3. Would this feature alone be useful for a simple model? Justify in one sentence.

# %% [markdown]
# ---
# ## Task 7 — Correlation

# %%
# Heatmap of numeric column correlations
# plt.figure(figsize=(10, 8))
# sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)

# %% [markdown]
# ### ✍️ Observation
#
# 1. List every pair of features with `|r| > 0.9`.
# 2. *Quick Check 2 from the lecture:* If two features correlate at 0.97, what do you do? (Drop one / keep both / add them / ignore.) Why?
# 3. Which feature has the strongest correlation with the target? Is it positive or negative?

# %% [markdown]
# ---
# ## Findings (final summary cell)
#
# Write a complete summary in markdown with these exact headings:
#
# ### 1. Three things I learned about this dataset
# (Bullets)
#
# ### 2. Red flags I noticed
# Anything that suggests:
# - A near-zero-variance column (Quick Check 1)
# - Multicollinearity / |r|>0.9 redundancy (Quick Check 2)
# - Imbalance that breaks accuracy as a metric (Quick Check 3)
# - Missingness that may carry signal (Quick Check 4)
# - Possible *data leakage* — a feature whose value would only exist *after* the target is known (Quick Check 5)
#
# ### 3. One question this data raises that EDA alone cannot answer
# (One paragraph)

# %% [markdown]
# ---
# ## Checkpoint Quiz (5 questions from the lecture page)
#
# Answer all 5 in markdown — these will be discussed at the start of Module 3.
#
# 1. A column where 99% of rows have the same value is — highly predictive / near-zero variance / the target / a bug?
# 2. Two features correlate at 0.97. What do you do?
# 3. Target is 0.2% positive. A model predicting 'no' always gets 99.8% accuracy. What does this show?
# 4. A column is 60% missing. First move?
# 5. You find `churn_recorded_at` in a dataset predicting `churned`. What do you do?
#
# For each, give the answer letter AND a one-sentence justification.
